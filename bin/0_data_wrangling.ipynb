# %%
# sample tiles from scanb_malmo with philips and xr1/2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import glob
import tarfile
from tqdm import tqdm
import os
import shutil

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', 0)   # show all columns
pd.set_option('display.width', 0)         # no line wrapping

# %%
# df for feature extraction

# # Fast CSV read & filter
# csv_path = 
# usecols = [col_name, "scanner_model_new", "split", "blur"]
# df = pd.read_csv(csv_path, usecols=usecols, dtype={col_name:str, "scanner_model_new":str, "split":str})
# df = df.dropna(subset=[col_name, "scanner_model_new", "split"]).copy()
# df["path"] = df[col_name].astype(str).str.strip()
# df = df[df["blur"]>250]

# %%
# Define stratified split function

def stratified_split_one_df_tile(df, var, n_train=10000, n_test=2000, random_state=24, split_col="split"):
    """
    Returns one DataFrame containing only the selected rows, with a `split` column.
    - var: column to stratify on (e.g., 'scanner_model')
    - n_train, n_test: per-stratum targets
    - If a stratum has fewer rows than requested, it will take as many as possible (train first).
    """
    rng = random_state
    df_shuf = df.sample(frac=1, random_state=rng)  # shuffle once for reproducibility

    labels = []  # collect (index, split_label)

    for level, g in df_shuf.groupby(var, sort=False, group_keys=False):
        need_train = n_train
        need_test  = n_test
        total = len(g)

        n_train_take = min(need_train, total)
        g_train = g.sample(n=n_train_take, random_state=12)

        g_rest = g.drop(g_train.index)
        n_test_take = min(need_test, len(g_rest))
        g_test = g_rest.sample(n=n_test_take, random_state=12)

        if total < (need_train + need_test):
            print(f"[warn] '{level}': only {total} rows; took train={n_train_take}, test={n_test_take}.")

        labels.extend([(idx, "train") for idx in g_train.index])
        labels.extend([(idx, "test")  for idx in g_test.index])

    # Build output DF of selected rows only, with split column
    selected_idx = [i for i, _ in labels]
    split_map = dict(labels)

    out = df.loc[selected_idx].copy()
    out[split_col] = out.index.map(split_map)

    # sanity prints
    print("\nPer-stratum counts:")
    print(out.groupby([var, split_col]).size().unstack(fill_value=0))

    # ensure no overlap & only requested rows
    assert set(out[split_col].unique()) <= {"train","test"}
    return out




def stratified_split_one_df_slide(df, var, n_train=500, n_test=100, random_state=42, split_col="split"):
    """
    Returns one DataFrame containing only the selected rows, with a `split` column.
    - var: column to stratify on (e.g., 'scanner_model')
    - n_train, n_test: per-stratum targets
    - If a stratum has fewer rows than requested, it will take as many as possible (train first).
    """
    rng = random_state
    df_uniq = df.drop_duplicates(subset=['file_name'])  # ensure one row per WSI
    df_shuf = df_uniq.sample(frac=1, random_state=rng)  # shuffle once for reproducibility
    

    labels = []  # collect (index, split_label)

    for level, g in df_shuf.groupby(var, sort=False, group_keys=False):
        need_train = n_train
        need_test  = n_test
        total = len(g)

        n_train_take = min(need_train, total)
        g_train = g.sample(n=n_train_take, random_state=12)

        g_rest = g.drop(g_train.index)
        n_test_take = min(need_test, len(g_rest))
        g_test = g_rest.sample(n=n_test_take, random_state=12)

        if total < (need_train + need_test):
            print(f"[warn] '{level}': only {total} rows; took train={n_train_take}, test={n_test_take}.")

        labels.extend([(idx, "train") for idx in g_train.index])
        labels.extend([(idx, "test")  for idx in g_test.index])

    # Build output DF of selected rows only, with split column
    selected_idx = [i for i, _ in labels]
    split_map = dict(labels)

    out = df.loc[selected_idx].copy()
    out[split_col] = out.index.map(split_map)

    # sanity prints
    print("\nPer-stratum counts:")
    print(out.groupby([var, split_col]).size().unstack(fill_value=0))

    # ensure no overlap & only requested rows
    assert set(out[split_col].unique()) <= {"train","test"}
    df_train = df[df.file_name.isin(out[out[split_col]=="train"].file_name.unique())]
    df_test = df[df.file_name.isin(out[out[split_col]=="test"].file_name.unique())]

    return out, df_train, df_test

# %% [markdown]
# #### Read in first batch of crude tiles

# %%
file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_1/dataframes/all_tiles_blur.csv"
batch_1 = pd.read_csv(file_path)
batch_1.file_name.nunique()
# Out:
# 611

# %%
# batch_1 crude tiles with macenko_blur
file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_1/dataframes/all_tiles_blur.csv"
batch_1 = pd.read_csv(file_path)

# wsi list with scanner_model
df_wsi = pd.read_csv("/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/df_batch_SCANB_Malmo_224x224.csv", index_col=False)
len(df_wsi)
df_wsi = df_wsi.rename(columns={"slide_filename": "file_name"})

# merge with tile list
batch_1= pd.merge(batch_1, df_wsi[['file_name', 'scanner_model']], on = 'file_name', how='left')

#mask = (batch_1['tissue_proportion']==1) & (batch_1['macenko_blur']> 500) & (batch_1['scanner_model'].isin(['XR2', 'PHILIPS', 'XR1']))
mask = batch_1['scanner_model'].isin(['XR2', 'PHILIPS', 'XR1']) # make it general to use all tiles 
batch_1_select = batch_1[mask]

print(len(batch_1))
print(len(batch_1_select))


print(batch_1_select.scanner_model.value_counts(normalize=True))
batch_1_select['scanner_model_new'] = np.where(
    batch_1_select['scanner_model'].isin(['XR1', 'XR2']),
    'XR',
    'PHILIPS')


print(f'{batch_1_select.file_name.nunique()}, unique wsis in selected set')
# Out:
# 14338543
# 12494647
# scanner_model
# PHILIPS    0.522985
# XR1        0.273281
# XR2        0.203733
# Name: proportion, dtype: float64
# /tmp/ipykernel_19622/2889109967.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch_1_select['scanner_model_new'] = np.where(
# 531, unique wsis in selected set

# %%
df_wsi.keys()
# Out:
# Index(['scanner_model', 'study_name', 'site', 'piece', 'piece2', 'stain',
#        'ihc_antibody', 'fraction_for_ihc_biomarker_assessment', 'preparation',
#        'rescan', 'scan_timestamp', 'Row_ID_key_n8278', 'multiple_RiDs',
#        'multiple_RiD_values', 'new_wsi_uniq_id', 'new_file_name', 'exclusion',
#        'exclusion_criteria', 'comment', 'select_primary', 'primary_selection',
#        'total_slides', 'total_he', 'largest_identified_tumor', 'file_name',
#        'total_tumor_area_mm2', 'File Path', 'exists', 'file_size',
#        'cumsum_size', 'Batch Name'],
#       dtype='object')

# %%
print(df_wsi.groupby('scanner_model')['file_name'].nunique())
# print(df_wsi.groupby('scanner_model')['tile_name'].nunique())
# Out:
# scanner_model
# APERIO       8
# PHILIPS    629
# S360       264
# XR1        503
# XR2        445
# Name: file_name, dtype: int64

# %%
print(batch_1_select.groupby('scanner_model_new')['file_name'].nunique())
print(batch_1_select.groupby('scanner_model_new')['tile_name'].nunique())
# Out:
# scanner_model_new
# PHILIPS    204
# XR         327
# Name: file_name, dtype: int64
# scanner_model_new
# PHILIPS    6534519
# XR         5960128
# Name: tile_name, dtype: int64

# %%
# sperate pools of wsis for train and test, slect 300 wsis for training pool and 200 wsis for test pool, each has balanced scanner_model_new
_, df_train, df_test = stratified_split_one_df_slide(batch_1_select, 
                                                     var='scanner_model_new',
                                                     n_train=150, 
                                                     n_test=50,
                                                     random_state=42)  # or your column name
print(f'train tiles: {len(df_train)}, test tiles {len(df_test)}')
df_train.scanner_model_new.value_counts()
# Out:
# Per-stratum counts:
# split              test  train
# scanner_model_new
# PHILIPS              50    150
# XR                   50    150
# train tiles: 7318324, test tiles 2615246
# scanner_model_new
# PHILIPS    4733590
# XR         2584734
# Name: count, dtype: int64

# %%
# Training samples: select tiles for training from training wsi pool, slect 5 million tiles for training and 20000 tiles for validation, each has balanced scanner_model_new
df_train_split = stratified_split_one_df_tile(df_train, 
                                            var='scanner_model_new',
                                            random_state=32, 
                                            n_train=2500000, 
                                            n_test=10000)  # or your column name
df_train_split['folder_name'] = (
    '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/' + 
    df_train_split['file_name'] + '/' + df_train_split['file_name'] + '/')

df_train_split['crude_tile_path'] = df_train_split['folder_name'] + df_train_split['tile_name']
df_train_split.to_csv("/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_train.csv", 
                      index=False)
# Out:
# Per-stratum counts:
# split               test    train
# scanner_model_new
# PHILIPS            10000  2500000
# XR                 10000  2500000

# %%
# Testing samples: use all tiles from test wsi pool
df_test['split'] = 'test'
df_test['folder_name'] = (
    '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/' + df_test['file_name'] + '/' + df_test['file_name'] + '/')

df_test['crude_tile_path'] = df_test['folder_name'] + df_test['tile_name']
df_test.to_csv("/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_test.csv"
               ,index=False)
# Out:
# /tmp/ipykernel_3422223/3645872904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['split'] = 'test'
# /tmp/ipykernel_3422223/3645872904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['folder_name'] = (
# /tmp/ipykernel_3422223/3645872904.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# #### select the same tiles as in the test set, but with Macenko normalization

# %%
# read in test set
df_test = pd.read_csv("/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_test.csv"
               ,index_col=False)
len(df_test)
# Out:
# 2615246

# %%
# read in machenko processed tiles for test set
file_path_macenko = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_1/dataframes/all_macenko_tiles.pkl"
batch_1_macenko = pd.read_pickle(file_path_macenko)
batch_1_macenko_select = batch_1_macenko[batch_1_macenko['file_name'].isin(df_test['file_name'].unique().tolist())]
batch_1_macenko_select.head();
# Out:
#                                           file_name  ...                                                                                                                                                                                            macenko_tile_path
# 127013  SCANB_MALMO_RiDn2806_slide_109936_WSI_clean  ...  /tmp/conboi/SCANB_Malmo_proc_data/batches/Batch_1/macenko_normalisation/tiles_macenko/SCANB_MALMO_RiDn2806_slide_109936_WSI_clean/SCANB_MALMO_RiDn2806_slide_109936_WSI_clean_0_405_29232_29637_macenko.jpg
# 127014  SCANB_MALMO_RiDn2806_slide_109936_WSI_clean  ...  /tmp/conboi/SCANB_Malmo_proc_data/batches/Batch_1/macenko_normalisation/tiles_macenko/SCANB_MALMO_RiDn2806_slide_109936_WSI_clean/SCANB_MALMO_RiDn2806_slide_109936_WSI_clean_0_405_29638_30043_macenko.jpg
# ...

# %%
# correct tile paths
batch_1_macenko_select['folder_name'] = (
    '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/macenko_normalisation/tiles_macenko/' + batch_1_macenko_select['file_name'] + '/' + batch_1_macenko_select['file_name'] + '/')
batch_1_macenko_select['macenko_tile_name'] = batch_1_macenko_select['macenko_tile_path'].str.split('/').str[-1]
batch_1_macenko_select['macenko_tile_path'] =batch_1_macenko_select['folder_name'] + batch_1_macenko_select['macenko_tile_name']
batch_1_macenko_select = batch_1_macenko_select.reset_index(drop=True)
batch_1_macenko_select.to_csv("/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_test_macenko.csv"
               ,index=False)
# Out:
# /tmp/ipykernel_22366/1926767189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch_1_macenko_select['folder_name'] = (
# /tmp/ipykernel_22366/1926767189.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch_1_macenko_select['macenko_tile_name'] = batch_1_macenko_select['macenko_tile_path'].str.split('/').str[-1]
# /tmp/ipykernel_22366/1926767189.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
len(batch_1_macenko_select)
# Out:
# 2615246

# %%
import gc
gc.collect()
# Out:
# 21

# %% [markdown]
# # New data using more than one scanner

# %%
# wsi list with scanner_model
df_wsi = pd.read_csv("/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/df_batch_SCANB_Malmo_224x224.csv", index_col=False)
len(df_wsi)
df_wsi = df_wsi.rename(columns={"slide_filename": "file_name"})

# batch_1 crude tiles with macenko_blur
file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_1/dataframes/all_tiles_blur.csv"
batch_1 = pd.read_csv(file_path)

file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_2/dataframes/all_tiles_blur.csv"
batch_2 = pd.read_csv(file_path)

file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_3/dataframes/all_tiles_blur.csv"
batch_3 = pd.read_csv(file_path)

batch_1_2 = pd.concat([batch_1, batch_2, batch_3])

# merge with tile list
batch_1_2= pd.merge(batch_1_2, df_wsi[['file_name', 'scanner_model']], on = 'file_name', how='left')

#mask = (batch_1['tissue_proportion']==1) & (batch_1['macenko_blur']> 500) & (batch_1['scanner_model'].isin(['XR2', 'PHILIPS', 'XR1']))
mask = batch_1_2['scanner_model'].isin(['S360']) # make it general to use all tiles 
S360_select = batch_1_2[mask]


print(S360_select.scanner_model.value_counts(normalize=True))
S360_select['scanner_model_new'] = S360_select['scanner_model']


print(f'{S360_select.file_name.nunique()}, unique wsis in selected set')
# Out:
# scanner_model
# S360    1.0
# Name: proportion, dtype: float64
# /tmp/ipykernel_166301/1280962330.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S360_select['scanner_model_new'] = S360_select['scanner_model']
# 263, unique wsis in selected set

# %%
print(S360_select.groupby('scanner_model')['file_name'].nunique())
print(S360_select.scanner_model.value_counts())
# Out:
# scanner_model
# S360    263
# Name: file_name, dtype: int64
# scanner_model
# S360    5838478
# Name: count, dtype: int64

# %%
for i in range(1,5):
    # file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_"+ str(i) +"/dataframes/all_tiles_blur.csv"
    # batch = pd.read_csv(file_path)
    # # merge with tile list
    # batch= pd.merge(batch, df_wsi[['file_name', 'scanner_model']], on = 'file_name', how='left')
    # print(batch.groupby('scanner_model')['file_name'].nunique())
# Out:
# scanner_model
# APERIO       2
# PHILIPS    204
# S360        78
# XR1        189
# XR2        138
# Name: file_name, dtype: int64
# scanner_model
# APERIO       3
# PHILIPS    214
# S360       101
# XR1        155
# XR2        147
# Name: file_name, dtype: int64
# scanner_model
# APERIO       3
# PHILIPS    208
# S360        84
# XR1        155
# XR2        156
# Name: file_name, dtype: int64
# scanner_model
# PHILIPS    3
# S360       1
# XR1        4
# XR2        4
# Name: file_name, dtype: int64

# %%
62+83+78
# Out:
# 223

# %%
# sperate pools of wsis for train and test, slect 300 wsis for training pool and 200 wsis for test pool, each has balanced scanner_model_new
_, df_train_360, df_test_360 = stratified_split_one_df_slide(S360_select, 
                                                     var='scanner_model_new',
                                                     n_train=150, 
                                                     n_test=50,
                                                     random_state=42)  # or your column name
print(f'train tiles: {len(df_train_360)}, test tiles {len(df_test_360)}')
df_train_360.scanner_model_new.value_counts()
# Out:
# Per-stratum counts:
# split              test  train
# scanner_model_new
# S360                 50    150
# train tiles: 3242720, test tiles 1167979
# scanner_model_new
# S360    3242720
# Name: count, dtype: int64

# %%
# Training samples: select tiles for training from training wsi pool, slect 5 million tiles for training and 20000 tiles for validation, each has balanced scanner_model_new
df_train_split_360 = stratified_split_one_df_tile(df_train_360, 
                                            var='scanner_model_new',
                                            random_state=32, 
                                            n_train=2500000, 
                                            n_test=10000)  # or your column name
# df_train_split['folder_name'] = (
#     '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/' + 
#     df_train_split['file_name'] + '/' + df_train_split['file_name'] + '/')

# df_train_split['crude_tile_path'] = df_train_split['folder_name'] + df_train_split['tile_name']
# df_train_split.to_csv("/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_train.csv", 
#                       index=False)
# Out:
# Per-stratum counts:
# split               test    train
# scanner_model_new
# S360               10000  2500000

# %%
df_train_split_360.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_train_ongoing.csv", 
                      index=False)

df_test_360.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_test_ongoing.csv"
               ,index=False)

# %%
df_train_split_360['crude_tile_path'].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches/', '', regex=False).to_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/s360_train_relative_file_list.txt', index=False, header=False)
df_test_360['crude_tile_path'].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches/', '', regex=False).to_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/s360_test_relative_file_list.txt', index=False, header=False)
df_test_360['crude_tile_path'].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches/', '', regex=False)
# Out:
# 980070          Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean_4410_4850_88200_88640.jpg
# 980071          Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean_4410_4850_88641_89081.jpg
# 980072          Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean_4851_5291_43218_43658.jpg
# 980073          Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean_4851_5291_43659_44099.jpg
# 980074          Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean_4851_5291_87318_87758.jpg
#                                                                            ...
# 41952572    Batch_3/tiles/SCANB_MALMO_RiDn1173_slide_514000_WSI_clean/SCANB_MALMO_RiDn1173_slide_514000_WSI_clean_79821_80261_110250_110690.jpg
# ...

# %% [markdown]
# Now we need to copy files.
# - Checked with Bojing.
#
# Should copy the files keeping the folder structure /Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean_4410_4850_88200_88640.jpg
# RUN FROM /home/ferbue/Image-Adaptive-3DLUT/
# the syntax --files-from=relative_list.txt source_folder dst_folder
# nohup rsync -av --info=progress2 --files-from=/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/s360_test_relative_file_list.txt /mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/ /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/ > rsync_log_s360_test.txt 2>&1 &
# 170738 PID

# %%
df_train_split_360
# Out:
#                                             file_name  ...  split
# 34583992  SCANB_MALMO_RiDn4550_slide_135750_WSI_clean  ...  train
# 13068767  SCANB_MALMO_RiDn2010_slide_751619_WSI_clean  ...  train
# 30999376  SCANB_MALMO_RiDn4883_slide_885306_WSI_clean  ...  train
# 41400159  SCANB_MALMO_RiDn7987_slide_445333_WSI_clean  ...  train
# 23332913  SCANB_MALMO_RiDn2943_slide_695751_WSI_clean  ...  train
# ...                                               ...  ...    ...
# 32485419  SCANB_MALMO_RiDn6246_slide_829109_WSI_clean  ...   test
# 28054755  SCANB_MALMO_RiDn5614_slide_649156_WSI_clean  ...   test
# 34245178  SCANB_MALMO_RiDn7911_slide_509423_WSI_clean  ...   test
# 19429754  SCANB_MALMO_RiDn1660_slide_692168_WSI_clean  ...   test
# 29440030  SCANB_MALMO_RiDn6754_slide_792508_WSI_clean  ...   test
#
# [2510000 rows x 19 columns]

# %%
df_train_split_360['crude_tile_path'].str.rsplit('/', n=1, expand=True)[0].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches','/mnt/ssd/bojing/Image-Adaptive-3DLUT/data')+ '/'+df_train_split_360['file_name'] + '/'
# Out:
# 34583992    /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_3/tiles/SCANB_MALMO_RiDn4550_slide_135750_WSI_clean/SCANB_MALMO_RiDn4550_slide_135750_WSI_clean/
# 13068767    /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn2010_slide_751619_WSI_clean/SCANB_MALMO_RiDn2010_slide_751619_WSI_clean/
# 30999376    /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_3/tiles/SCANB_MALMO_RiDn4883_slide_885306_WSI_clean/SCANB_MALMO_RiDn4883_slide_885306_WSI_clean/
# 41400159    /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_3/tiles/SCANB_MALMO_RiDn7987_slide_445333_WSI_clean/SCANB_MALMO_RiDn7987_slide_445333_WSI_clean/
# 23332913    /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_2/tiles/SCANB_MALMO_RiDn2943_slide_695751_WSI_clean/SCANB_MALMO_RiDn2943_slide_695751_WSI_clean/
#                                                                                   ...
# ...

# %%
df_train_split_360['folder_name'] = (
    df_train_split_360['crude_tile_path'].str.rsplit('/', n=1, expand=True)[0].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches','/mnt/ssd/bojing/Image-Adaptive-3DLUT/data')+ '/'+df_train_split_360['file_name'] + '/')

df_train_split_360['crude_tile_path'] = df_train_split_360['folder_name'] + df_train_split_360['tile_name'] # 


# Testing samples: use all tiles from test wsi pool
df_test_360['split'] = 'test'
df_test_360['folder_name'] = (
    df_test_360['crude_tile_path'].str.rsplit('/', n=1, expand=True)[0].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches','/mnt/ssd/bojing/Image-Adaptive-3DLUT/data')+ '/'+df_test_360['file_name'] + '/')

df_test_360['crude_tile_path'] = df_test_360['folder_name'] + df_test_360['tile_name']
# Out:
# /tmp/ipykernel_166301/483537277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_360['split'] = 'test'
# /tmp/ipykernel_166301/483537277.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_360['folder_name'] = (
# /tmp/ipykernel_166301/483537277.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_test_360
# Out:
#                                             file_name  ...                                                                                                                                       folder_name
# 980070    SCANB_MALMO_RiDn4140_slide_671222_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/
# 980071    SCANB_MALMO_RiDn4140_slide_671222_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/
# 980072    SCANB_MALMO_RiDn4140_slide_671222_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/
# ...

# %%
#Read previous Philips_XR Data
test_path = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_test.csv'
train_path = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_train.csv'

prev_train_df = pd.read_csv(train_path ,index_col=False)
prev_train_df.scanner_model_new.value_counts()
# Out:
# scanner_model_new
# PHILIPS    2510000
# XR         2510000
# Name: count, dtype: int64

# %%
train_xr_df = prev_train_df[prev_train_df['scanner_model_new']=='XR']
print(len(train_xr_df))
train_philips_df = prev_train_df[prev_train_df['scanner_model_new']=='PHILIPS']
print(len(train_philips_df))
# Out:
# 2510000
# 2510000

# %%
df_train_split_s360_xr = pd.concat([df_train_split_360, train_xr_df])
df_train_split_s360_xr.scanner_model_new.value_counts()
# Out:
# scanner_model_new
# S360    2510000
# XR      2510000
# Name: count, dtype: int64

# %%
df_train_split_s360_xr.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_train.csv", 
                      index=False)

# %%
#Read previous Philips_XR Data

prev_test_df = pd.read_csv(test_path ,index_col=False)
prev_test_df.scanner_model_new.value_counts()

test_xr_df = prev_test_df[prev_test_df['scanner_model_new']=='XR']
print(len(test_xr_df))
test_philips_df = prev_test_df[prev_test_df['scanner_model_new']=='PHILIPS']
print(len(test_philips_df))
# Out:
# 958549
# 1656697

# %%
df_test_split_s360_xr = pd.concat([df_test_360, test_xr_df])
df_test_split_s360_xr.scanner_model_new.value_counts()
# Out:
# scanner_model_new
# S360    1167979
# XR       958549
# Name: count, dtype: int64

# %%
df_test_split_s360_xr.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_test.csv", 
                      index=False)

# %%
df_train_split_s360_xr_philips = pd.concat([df_train_split_360, train_philips_df, train_xr_df])
print(df_train_split_s360_xr_philips.scanner_model_new.value_counts())
df_train_split_s360_xr_philips.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_philips_train.csv", index=False)
# Out:
# scanner_model_new
# S360       2510000
# PHILIPS    2510000
# XR         2510000
# Name: count, dtype: int64

# %%
print(df_train_split_s360_xr_philips.scanner_model_new.value_counts())
# Out:
# scanner_model_new
# S360       2510000
# PHILIPS    2510000
# XR         2510000
# Name: count, dtype: int64

# %%
df_test_split_s360_xr_philips = pd.concat([df_test_360, test_philips_df, test_xr_df])
print(df_test_split_s360_xr_philips.scanner_model_new.value_counts())
df_test_split_s360_xr_philips.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_philips_test.csv", index=False)
# Out:
# scanner_model_new
# PHILIPS    1656697
# S360       1167979
# XR          958549
# Name: count, dtype: int64

# %%
df_test_360[df_test_360['file_name']==wsi]
# Out:
#                                            file_name  ...                                                                                                                                       folder_name
# 980070   SCANB_MALMO_RiDn4140_slide_671222_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/
# 980071   SCANB_MALMO_RiDn4140_slide_671222_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/
# 980072   SCANB_MALMO_RiDn4140_slide_671222_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/SCANB_MALMO_RiDn4140_slide_671222_WSI_clean/
# ...

# %%
# Moving the data

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/'
target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'

for wsi in tqdm(df_test_360['file_name'].unique()[:]):
    # print(wsi)
    tar_file = glob.glob(source_folder+'*/tiles/'+wsi+'/*.tar')[0]
    batch = int(tar_file.replace(source_folder,'').split('/')[0].split('_')[-1])
    # if batch != 1: #I don't need to copy Batch 1, plus I don't have the writing permission
    if not os.path.isdir(target_folder_wsi): #
        target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/' #Double wsi to match what was previously done
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)
# Out:
# 100%|██████████| 50/50 [01:22<00:00,  1.65s/it]

# %%
# Repeating for missing files in processed data

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing=[]

for wsi in tqdm(df_test_360['file_name'].unique()[:]):
    # print(wsi)
    tar_file = glob.glob(source_folder+'*/tiles/'+wsi+'/*.tar')[0]
    batch = int(tar_file.replace(source_folder,'').split('/')[0].split('_')[-1])
    # if batch != 1: #I don't need to copy Batch 1, plus I don't have the writing permission
    if not os.path.isdir(target_folder_wsi): #
        missing.append(wsi)
        target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/' #Double wsi to match what was previously done
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)

print('missing:',len(missing))
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 28.70it/s]
# missing: 0

# %%
for wsi in tqdm(df_train_360['file_name'].unique()[:]):
    # print(wsi)
    tar_file = glob.glob(source_folder+'*/tiles/'+wsi+'/*.tar')[0]
    batch = int(tar_file.replace(source_folder,'').split('/')[0].split('_')[-1])
    if batch != 1:
        target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/' #Double wsi to match what was previously done
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)
# Out:
# 100%|██████████| 150/150 [04:07<00:00,  1.65s/it]

# %%
# Out:
#                                            file_name  ...                                                                                                                                       folder_name
# 288      SCANB_MALMO_RiDn2162_slide_111129_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn2162_slide_111129_WSI_clean/SCANB_MALMO_RiDn2162_slide_111129_WSI_clean/
# 386      SCANB_MALMO_RiDn2162_slide_111129_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn2162_slide_111129_WSI_clean/SCANB_MALMO_RiDn2162_slide_111129_WSI_clean/
# 1243     SCANB_MALMO_RiDn2162_slide_111129_WSI_clean  ...  /mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/tiles/SCANB_MALMO_RiDn2162_slide_111129_WSI_clean/SCANB_MALMO_RiDn2162_slide_111129_WSI_clean/
# ...

# %%
check_df = pd.read_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_philips_train.csv")

missing = []
for wsi in tqdm(df_test_360['file_name'].unique()[:]):
    tar_file = glob.glob(source_folder+'*/tiles/'+wsi+'/*.tar')[0]
    batch = tar_file.replace(source_folder,'').split('/')[0]
    if batch!= 'Batch_1':
        missing.append(wsi)
        check_df.loc[check_df['file_name'] == wsi, 'folder_name'] = check_df.loc[check_df['file_name'] == wsi, 'folder_name'].str.replace('Batch_1', batch, regex=False)
        check_df.loc[check_df['file_name'] == wsi, 'crude_tile_path'] = check_df.loc[check_df['file_name'] == wsi, 'crude_tile_path'].str.replace('Batch_1', batch, regex=False)
print(len(missing))
# Out:
# 100%|██████████| 50/50 [01:43<00:00,  2.07s/it]
# 48

# %%
check_df.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_philips_test.csv", index=False)

# %%
# check_df[check_df['file_name']=='SCANB_MALMO_RiDn2162_slide_111129_WSI_clean']
'SCANB_MALMO_RiDn2162_slide_111129_WSI_clean' in df_train_360['file_name'].unique()[:]

glob.glob(target_folder_base+'/*/tiles/'+ 'SCANB_MALMO_RiDn2162_slide_111129_WSI_clean')
# Out:
# ['/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_2/tiles/SCANB_MALMO_RiDn2162_slide_111129_WSI_clean']

# %% [markdown]
# # Copy MACENKO S360
#
# Macenko tiles are sorted in a different way in '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/' and assigned to different batches. I copied them wrongly, had to re-do the copy to solve this issue.

# %%
df_test_split_s360_xr_philips = pd.read_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_philips_test.csv")

# %%
df_test_360 = df_test_split_s360_xr_philips[df_test_split_s360_xr_philips['scanner_model_new']=='S360']

# %%
# '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'+ '*/macenko_normalisation/tiles_macenko/' SCANB_MALMO_RiDn0034_slide_856400_WSI_clean '/SCANB_MALMO_RiDn0034_slide_856400_WSI_clean.tar'
# source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
# target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'

# wsi = 
# target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/'
# glob.glob(source_folder+'*/tiles/'+wsi+'/*.tar')[0]

'/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/macenko_normalisation/tiles_macenko/SCANB_MALMO_RiDn0038_slide_161731_WSI_clean/SCANB_MALMO_RiDn0038_slide_161731_WSI_clean'

# %%
#Cleaning the mess
target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
for i in tqdm(range(5,33)):
    #Check if there is a wrongly copied folder. Batch >= 4 with only a macenko_normalisation folder
    iter_target = target_folder_base+'Batch_'+str(i)
    folder_list = glob.glob(iter_target+'/*')
    if len(folder_list)==1 and 'macenko_normalisation' in folder_list[0]:
        # shutil.rmtree(iter_target)

# shutil.rmtree('/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_2/macenko_normalisation/') #Only macenko for these
# shutil.rmtree('/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_3/macenko_normalisation/')
# Out:
# 100%|██████████| 28/28 [01:08<00:00,  2.45s/it]

# %%
# MACENKO ORIGINAL COPY

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing=[]

for wsi in tqdm(df_test_360['file_name'].unique()[:]):
    # print(wsi)
    tar_list = glob.glob(source_folder+'*/macenko_normalisation/tiles_macenko/'+wsi+'/*.tar')
    if len(tar_list)>1:
        print('Warning: ', wsi, len(tar_list))
        print(tar_list)
    tar_file = tar_list[0]
    batch = int(tar_file.replace(source_folder,'').split('/')[0].split('_')[-1])
    # if batch != 1: #I don't need to copy Batch 1, plus I don't have the writing permission
    target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/' #Double wsi to match what was previously done
    if not os.path.isdir(target_folder_wsi): #
        missing.append(wsi)
        
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)

print('missing:',len(missing))
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 61.77it/s]
# missing: 0

# %%
#WSI aggregation
df_tst_360_wsi = (
    df_test_360.groupby('file_name')
      .agg(lambda x: x.mean() if x.dtype != 'object' else x.iloc[0])
      .reset_index()
)

# %%
source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
# target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing=[]

for i, row in df_tst_360_wsi[['file_name','folder_name']].iterrows():
    wsi = row['file_name']
    target_folder_base = row['folder_name']
    tar_list = glob.glob(source_folder+'*/macenko_normalisation/tiles_macenko/'+wsi+'/*.tar')
    tar_file = tar_list[0]

    target_folder_wsi = target_folder_base.replace('tiles','macenko_normalisation/tiles_macenko') #Double wsi to match what was previously done
    if not os.path.isdir(target_folder_wsi): #
        missing.append(target_folder_wsi)
        
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)

print('missing:',len(missing))
# Out:
# missing: 35

# %%
df_train_split_s360_xr_philips = pd.read_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_philips_train.csv")
df_train_360 = df_train_split_s360_xr_philips[df_train_split_s360_xr_philips['scanner_model_new']=='S360']

# %%
#WSI aggregation
df_train_360_wsi = (
    df_train_360.groupby('file_name')
      .agg(lambda x: x.mean() if x.dtype != 'object' else x.iloc[0])
      .reset_index()
)

# %%
len(df_train_360_wsi)
# Out:
# 150

# %%
source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
# target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing=[]

for i, row in tqdm(df_train_360_wsi[['file_name','folder_name']].iterrows()):
    wsi = row['file_name']
    target_folder_base = row['folder_name']
    tar_list = glob.glob(source_folder+'*/macenko_normalisation/tiles_macenko/'+wsi+'/*.tar')
    tar_file = tar_list[0]

    target_folder_wsi = target_folder_base.replace('tiles','macenko_normalisation/tiles_macenko') #Double wsi to match what was previously done
    if not os.path.isdir(target_folder_wsi): #
        missing.append(target_folder_wsi)
        
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)

print('missing:',len(missing))
# Out:
# 150it [04:21,  1.75s/it]
# missing: 110

# %%
tar_file
# Out:
# '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/Batch_21/macenko_normalisation/tiles_macenko/SCANB_MALMO_RiDn8168_slide_778457_WSI_clean/SCANB_MALMO_RiDn8168_slide_778457_WSI_clean.tar'

# %%
# MACENKO ORIGINAL COPY (MESSY)

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing=[]

for wsi in tqdm(df_train_360['file_name'].unique()[:]):
    # print(wsi)
    tar_file = glob.glob(source_folder+'*/macenko_normalisation/tiles_macenko/'+wsi+'/*.tar')[0]
    batch = int(tar_file.replace(source_folder,'').split('/')[0].split('_')[-1])
    # if batch != 1: #I don't need to copy Batch 1, plus I don't have the writing permission
    target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/' #Double wsi to match what was previously done

    if not os.path.isdir(target_folder_wsi): #
        missing.append(wsi)
        
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)


print('missing:',len(missing))
# Out:
# 100%|██████████| 150/150 [00:02<00:00, 55.73it/s]
# missing: 0

# %% [markdown]
# # Looking for other data sources

# %%
# file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/processed-data/SCANB_Malmo_pil_10.4_224px/batches/Batch_1/dataframes/all_tiles_blur.csv"
# wsi_file_path = "/mnt/chime-preprocessed_data/SCANB_Malmo/SCANB_Malmo_224x224/df_batch_SCANB_Malmo_224x224.csv"

# file_path = "/mnt/chime-preprocessed_data/SCANB_Kristianstad/SCANB_Kristianstad_224x224/processed-data/SCANB_Kristianstad_px/batches/Batch_1/dataframes/all_tiles_blur.csv"
# wsi_file_path = '/mnt/chime-preprocessed_data/SCANB_Kristianstad/SCANB_Kristianstad_224x224/df_batch_SCANB_Kristianstad_224x224.csv'
# scanner_model
# XR1    655
# XR2    931

# file_path = "/mnt/chimeracknas5data2/preproc-slides/CHIME_BREAST_KALMAR/v2/batches/Batch_1/dataframes/all_tiles_blur.csv"
# wsi_file_path = '/mnt/chimeracknas5data2/preproc-slides/CHIME_BREAST_KALMAR/v2/batches/Batch_1/dataframes/slides_df.pkl'
# Could find scanner source


file_path = "/mnt/chimeracknas5data2/preproc-slides/SCAN-B_LUND/v1/processed-data/SCAN-B-Lund_224px/batches/Batch_1/dataframes/all_tiles_blur.csv"
wsi_file_path = '/mnt/chimeracknas5data2/preproc-slides/SCAN-B_LUND/v1/df_batch_SCAN-B-Lund.csv'
# Could find scanner source

# batch_1 crude tiles with macenko_blur

batch_1 = pd.read_csv(file_path)

# wsi list with scanner_model
df_wsi = pd.read_csv(wsi_file_path, index_col=False)
len(df_wsi)
df_wsi = df_wsi.rename(columns={"slide_filename": "file_name"})

# merge with tile list
batch_1= pd.merge(batch_1, df_wsi[['file_name', 'scanner_model']], on = 'file_name', how='left')
print(df_wsi.groupby('scanner_model')['file_name'].nunique())
# print(df_wsi.groupby('scanner_model')['tile_name'].nunique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 29
#      26 df_wsi = df_wsi.rename(columns={"slide_filename": "file_name"})
#      28 # merge with tile list
# ---> 29 batch_1= pd.merge(batch_1, df_wsi[['file_name', 'scanner_model']], on = 'file_name', how='left')
#      30 print(df_wsi.groupby('scanner_model')['file_name'].nunique())
#      31 # print(df_wsi.groupby('scanner_model')['tile_name'].nunique())
#
# File ~/anaconda3/envs/chime_env_v2_lut/lib/python3.8/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
df_wsi = pd.read_csv('/mnt/chimeracknas5data2/preproc-slides/CHIME_BREAST_KALMAR/v2/df_batch_train_breast_FM_slides_kalmar.csv')

# %%
df_wsi.keys()
# Out:
# Index(['File Path', 'rid', 'exists', 'file_size', 'cumsum_size', 'Batch Name'], dtype='object')

# %% [markdown]
# # Constance info

# %%
# This dataset contains the metadata slide relevant
all_wsi = pd.read_csv("/mnt/chime-dataset_metadata/SCANB_Malmo/scanb_malmo_ffpe_lastscan_anonymised.csv")
all_wsi = all_wsi[all_wsi['stain'] =='HE']
all_aperio_wsi = all_wsi[all_wsi['scanner_model']=='APERIO']
aperio_wsi_names = all_aperio_wsi['new_file_name'].str.replace('.svs','')

# %%
aperio_wsi_names
# Out:
# 45       SCANB_MALMO_RiDn3243_slide_767742_WSI_clean
# 62       SCANB_MALMO_RiDn4357_slide_487951_WSI_clean
# 158      SCANB_MALMO_RiDn1197_slide_214473_WSI_clean
# 243      SCANB_MALMO_RiDn5158_slide_416852_WSI_clean
# 261      SCANB_MALMO_RiDn6401_slide_519075_WSI_clean
#                             ...
# 45598    SCANB_MALMO_RiDn1699_slide_157274_WSI_clean
# 45815    SCANB_MALMO_RiDn0779_slide_378810_WSI_clean
# 45859    SCANB_MALMO_RiDn5926_slide_507597_WSI_clean
# 45876    SCANB_MALMO_RiDn5563_slide_428274_WSI_clean
# 45905    SCANB_MALMO_RiDn5077_slide_574318_WSI_clean
# Name: new_file_name, Length: 930, dtype: object

# %%
print(all_wsi.groupby('scanner_model')['new_wsi_uniq_id'].nunique())
# print(df_wsi.groupby('scanner_model')['tile_name'].nunique())
# Out:
# scanner_model
# APERIO      930
# PHILIPS    7512
# S360       3908
# XR1        5866
# XR2        6855
# Name: new_wsi_uniq_id, dtype: int64

# %%
#This dataset was re- preprocessed after finding the issue. It contains way more slides than the one in ScanB_MALMO_224x224
# df_wsi_224 = pd.read_csv('/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/Batch_1/dataframes/all_tiles_blur.csv')
# len(df_wsi_224)
dfs = []
wsi_count = 0 
i=0
# batch_1 crude tiles with macenko_blur
while wsi_count<250:
    i+=1
    print('batch:',i)
    file_path = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/Batch_'+str(i)+'/dataframes/all_tiles_blur.csv'
    this_batch = pd.read_csv(file_path)
    aperio_batch = this_batch[this_batch['file_name'].isin(aperio_wsi_names)]
    this_count = aperio_batch['file_name'].nunique()
    wsi_count += this_count
    print(this_count, '/', wsi_count)
    dfs.append(aperio_batch)
# Out:
# batch: 1
# 29 / 29
# batch: 2
# 31 / 60
# batch: 3
# 29 / 89
# batch: 4
# 24 / 113
# batch: 5
# 17 / 130
# batch: 6
# 29 / 159
# batch: 7
# 30 / 189
# batch: 8
# 21 / 210
# batch: 9
# 29 / 239
# batch: 10
# 30 / 269

# %%
selected_aperio_df = pd.concat(dfs[:8], ignore_index=True)
print(selected_aperio_df['file_name'].nunique())
# Out:
# 210

# %%
selected_aperio_df['scanner_model']='APERIO'
selected_aperio_df['scanner_model_new']='APERIO'

# %%
# sperate pools of wsis for train and test, slect 150 wsis for training pool and 50 wsis for test pool, each has balanced scanner_model_new
_, df_train_Aperio, df_test_Aperio = stratified_split_one_df_slide(selected_aperio_df, 
                                                     var='scanner_model_new',
                                                     n_train=150, 
                                                     n_test=50,
                                                     random_state=42)  # or your column name
print(f'train tiles: {len(df_train_Aperio)}, test tiles {len(df_test_Aperio)}')
# Out:
# Per-stratum counts:
# split              test  train
# scanner_model_new
# APERIO               50    150
# train tiles: 1923551, test tiles 622481

# %%
# Training samples: select tiles for training from training wsi pool, training and validation
# Previous scanners use 2,500,000 patches for training and 10,000 for validation
# There are less here (background removal is better) 1923551 -- Not an issue since we were removing based in blur later. I will keep the validation size the same and adapt train
df_train_split_Aperio = stratified_split_one_df_tile(df_train_Aperio, 
                                            var='scanner_model_new',
                                            random_state=32, 
                                            n_train=1913551, 
                                            n_test=10000)  # or your column name
# Out:
# Per-stratum counts:
# split               test    train
# scanner_model_new
# APERIO             10000  1913551

# %%
df_train_split_Aperio['folder_name'] = (
    df_train_split_Aperio['crude_tile_path'].str.rsplit('/', n=1, expand=True)[0].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches','/mnt/ssd/bojing/Image-Adaptive-3DLUT/data')+ '/'+df_train_split_Aperio['file_name'] + '/')

df_train_split_Aperio['crude_tile_path'] = df_train_split_Aperio['folder_name'] + df_train_split_Aperio['tile_name'] # 


# Testing samples: use all tiles from test wsi pool
df_test_Aperio['split'] = 'test'
df_test_Aperio['folder_name'] = (
    df_test_Aperio['crude_tile_path'].str.rsplit('/', n=1, expand=True)[0].str.replace('/tmp/conboi/SCANB_Malmo_proc_data/batches','/mnt/ssd/bojing/Image-Adaptive-3DLUT/data')+ '/'+df_test_Aperio['file_name'] + '/')

df_test_Aperio['crude_tile_path'] = df_test_Aperio['folder_name'] + df_test_Aperio['tile_name']
# Out:
# /tmp/ipykernel_19622/3960299559.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_Aperio['split'] = 'test'
# /tmp/ipykernel_19622/3960299559.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_Aperio['folder_name'] = (
# /tmp/ipykernel_19622/3960299559.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_train_split_Aperio.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_Aperio_train_ongoing.csv", 
                      index=False)

df_test_Aperio.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_Aperio_test_ongoing.csv"
               ,index=False)

# %%
df_train_split_Aperio= pd.read_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_Aperio_train_ongoing.csv")

df_test_Aperio= pd.read_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_Aperio_test_ongoing.csv")

# %%
# Moving the data

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing = 0
for wsi in tqdm(df_test_Aperio['file_name'].unique()[:]):
    
    tar_file = glob.glob(source_folder+'*/tiles/'+wsi+'/*.tar')[0]
    batch = int(tar_file.replace(source_folder,'').split('/')[0].split('_')[-1])
    # print(wsi, batch)
    # if batch != 1: #I don't need to copy Batch 1, plus I don't have the writing permission
    target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/' #Double wsi to match what was previously done
    if not os.path.isdir(target_folder_wsi): # 
        missing+=1     
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)
print(missing)
# Out:
# 100%|██████████| 50/50 [01:06<00:00,  1.34s/it]
# 49

# %%
# Moving the data

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing = 0
for wsi in tqdm(df_train_split_Aperio['file_name'].unique()[:]):
    
    tar_file = glob.glob(source_folder+'*/tiles/'+wsi+'/*.tar')[0]
    batch = int(tar_file.replace(source_folder,'').split('/')[0].split('_')[-1])
    # print(wsi, batch)
    # if batch != 1: #I don't need to copy Batch 1, plus I don't have the writing permission
    target_folder_wsi = target_folder_base+tar_file.replace(source_folder,'').rsplit('/',1)[0]+'/'+wsi+'/' #Double wsi to match what was previously done
    if not os.path.isdir(target_folder_wsi): # 
        missing+=1     
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)
print(missing)
# Out:
# 100%|██████████| 150/150 [03:25<00:00,  1.37s/it]
# 150

# %%
#WSI aggregation
df_tst_wsi = (
    df_test_Aperio.groupby('file_name')
      .agg(lambda x: x.mean() if x.dtype != 'object' else x.iloc[0])
      .reset_index()
)

# %%
#Macenko 

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
# target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing=[]

for i, row in df_tst_wsi[['file_name','folder_name']].iterrows():
    wsi = row['file_name']
    target_folder_base = row['folder_name']
    tar_list = glob.glob(source_folder+'*/macenko_normalisation/tiles_macenko/'+wsi+'/*.tar')
    tar_file = tar_list[0]

    target_folder_wsi = target_folder_base.replace('tiles','macenko_normalisation/tiles_macenko') #Double wsi to match what was previously done
    if not os.path.isdir(target_folder_wsi): #
        missing.append(target_folder_wsi)
        
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)

print('missing:',len(missing))
# Out:
# missing: 38

# %%
#WSI aggregation
df_train_wsi = (
    df_train_split_Aperio.groupby('file_name')
      .agg(lambda x: x.mean() if x.dtype != 'object' else x.iloc[0])
      .reset_index()
)

# %%
#Macenko 

source_folder = '/mnt/chimeracknas5data2/preproc-slides/SCANB_MALMO/SCANB_Malmo_all_slides_224x224/batches/'
# target_folder_base = '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/'
missing=[]

for i, row in df_train_wsi[['file_name','folder_name']].iterrows():
    wsi = row['file_name']
    target_folder_base = row['folder_name']
    tar_list = glob.glob(source_folder+'*/macenko_normalisation/tiles_macenko/'+wsi+'/*.tar')
    tar_file = tar_list[0]

    target_folder_wsi = target_folder_base.replace('tiles','macenko_normalisation/tiles_macenko') #Double wsi to match what was previously done
    if not os.path.isdir(target_folder_wsi): #
        missing.append(target_folder_wsi)
        
        with tarfile.open(tar_file) as tar:
            tar.extractall(path=target_folder_wsi)

print('missing:',len(missing))
# Out:
# missing: 150

# %%
target_folder_wsi
# Out:
# '/mnt/ssd/bojing/Image-Adaptive-3DLUT/data/Batch_1/macenko_normalisation/tiles_macenko/SCANB_MALMO_RiDn1699_slide_123409_WSI_clean/SCANB_MALMO_RiDn1699_slide_123409_WSI_clean/'

# %%
df_train_split_aperio_xr = pd.concat([df_train_split_Aperio, train_xr_df])
print(df_train_split_aperio_xr.scanner_model_new.value_counts())
df_train_split_aperio_xr.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_aperio_xr_train.csv", index=False)
# Out:
# scanner_model_new
# XR        2510000
# APERIO    1923551
# Name: count, dtype: int64

# %%
df_test_aperio_xr = pd.concat([df_test_Aperio, test_xr_df])
print(df_test_aperio_xr.scanner_model_new.value_counts())
df_test_aperio_xr.to_csv("/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_aperio_xr_test.csv", index=False)
# Out:
# scanner_model_new
# XR        958549
# APERIO    622481
# Name: count, dtype: int64

# %% [markdown]
# # Merging everything together

# %%
dataframe_list = [
 '/mnt/ssd/bojing/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_train.csv',
 '/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_philips_xr_test.csv',
 '/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_train.csv',
 '/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_s360_xr_test.csv',
 '/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_aperio_xr_train.csv',
 '/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_aperio_xr_test.csv']

# %%
test_list = [f for f in dataframe_list if 'test' in f]
test_list

#get xr and first
df_list = []
for i, df_file in enumerate(test_list):
    print(i)
    iter_df = pd.read_csv(df_file)
    
    if i==0:
        xr_df = iter_df[iter_df['scanner_model_new']=='XR']
        df_list.append(xr_df)
    source_df = iter_df[iter_df['scanner_model_new']!='XR']
    df_list.append(source_df)

df_all = pd.concat(df_list)
df_all.scanner_model_new.value_counts()


# df_all.to_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_all_sources_test.csv', index=False)
# Out:
# 0
# 1
# 2
# scanner_model_new
# PHILIPS    1656697
# S360       1167979
# XR          958549
# APERIO      622481
# Name: count, dtype: int64

# %%
df_all.to_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_all_sources_test.csv', index=False)

# %%
df_all_wsi = (
    df_all.groupby('file_name')
      .agg(lambda x: x.mean() if x.dtype != 'object' else x.iloc[0])
      .reset_index()
)

df_all_wsi.scanner_model_new.value_counts()
# Out:
# scanner_model_new
# APERIO     50
# PHILIPS    50
# S360       50
# XR         50
# Name: count, dtype: int64

# %%
train_list = [f for f in dataframe_list if 'train' in f]
train_list

#get xr and first
df_list = []
for i, df_file in enumerate(train_list):
    print(i)
    iter_df = pd.read_csv(df_file)
    
    if i==0:
        xr_df = iter_df[iter_df['scanner_model_new']=='XR']
        df_list.append(xr_df)
    source_df = iter_df[iter_df['scanner_model_new']!='XR']
    df_list.append(source_df)

df_all = pd.concat(df_list)
df_all.scanner_model_new.value_counts()

print('saving')
df_all.to_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_all_sources_train.csv', index=False)
# Out:
# 0
# 1
# 2
# saving

# %%
df_all.scanner_model_new.value_counts()
# Out:
# scanner_model_new
# XR         2510000
# PHILIPS    2510000
# S360       2510000
# APERIO     1923551
# Name: count, dtype: int64

# %%
df_all_wsi = (
    df_all.groupby('file_name')
      .agg(lambda x: x.mean() if x.dtype != 'object' else x.iloc[0])
      .reset_index()
)

df_all_wsi.scanner_model_new.value_counts()
# Out:
# scanner_model_new
# S360       150
# APERIO     150
# PHILIPS    150
# XR         150
# Name: count, dtype: int64

# %% [markdown]
# # Validation is too big for quick training. Lets reduce

# %%
df_all = pd.read_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_all_sources_train.csv')

# %%
tst = np.sum(df_all['split']=='test')
train = np.sum(df_all['split']=='train') 
print(tst, train, tst+train)
# print()
# Out:
# 40000 9413551 9453551

# %%
df_train_split = stratified_split_one_df_tile(df_all[df_all['split']=='test'], 
                                            var='scanner_model_new',
                                            random_state=32, 
                                            n_train=0, 
                                            n_test=3000)  # or your column name

print(len(df_train_split))
# Out:
# Per-stratum counts:
# split              test
# scanner_model_new
# APERIO             3000
# PHILIPS            3000
# S360               3000
# XR                 3000
# 12000

# %%
df_train_split.to_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_all_sources_validation.csv', index=False)

# %%
df_all = pd.read_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_all_sources_test.csv')

# %%
df_all.keys()
# Out:
# Index(['file_name', 'file_format', 'tile_name', 'top_source', 'bottom_source',
#        'left_source', 'right_source', 'slide_h', 'slide_w', 'mpp',
#        'mpp_source', 'lvl', 'tissue_proportion', 'blur', 'crude_tile_path',
#        'macenko_blur', 'scanner_model', 'scanner_model_new', 'split',
#        'folder_name'],
#       dtype='object')

# %%
plt.hist(df_all['tissue_proportion'])
# Out:
# (array([  70107.,   59161.,   52269.,   48402.,   51218.,   47690.,
#           49199.,   54795.,   61359., 3911506.]),
#  array([0.05102041, 0.14591837, 0.24081633, 0.33571429, 0.43061224,
#         0.5255102 , 0.62040816, 0.71530612, 0.81020408, 0.90510204,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
print(len(df_all))
np.sum(df_all['macenko_blur']<250)
# Out:
# 4405706
# 921081

# %%
n_samples_per_wsi=1000
# tile_feat_sampled = features2.groupby("file_name", group_keys=False, sort=False).sample(n=n_samples_per_wsi, random_state=42) #Crashes if not enough tiles available
df_sampled = (
    df_all.groupby("file_name", group_keys=False)
    .apply(lambda x: x.sample(n=min(len(x), n_samples_per_wsi), random_state=42))
)

# %%
df_sampled.scanner_model_new.value_counts()
# Out:
# scanner_model_new
# PHILIPS    50000
# S360       50000
# XR         49446
# APERIO     49121
# Name: count, dtype: int64

# %%
df_sampled.to_csv('/mnt/ssd/ferbue/Image-Adaptive-3DLUT/dataframes/scanb_malmo_all_sources_test_reduced.csv', index=False)
